# %% [markdown]
# ##Travel Itinerary Builder using LLM (PromptTemplate + Chain)

# %%
# !pip install langchain langchain-google-genai google-generativeai

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from google.colab import userdata

name= input("Enter your name: ")
city= input(f"Hey {name}, Enter your city: ")
number_of_days= input("How many days you would travel: ")
travel_style= input("What is your travel style (relaxed/busy): ")
interests= input("What is your interest: ")

llm= ChatGoogleGenerativeAI(
    model="gemini-3-flash-preview",
    google_api_key=userdata.get('GOOGLE')
)

Day_p= PromptTemplate(
    template= " Must generate the plan as: Day 1, Day 2 … up to Day{number_of_days} and also take care of {city},{travel_style} and {interests}",
    input_variables= ["city", "number_of_days", "travel_style", "interests"]
)

time_blocks= PromptTemplate(
    template= "Each day of {Day_p} must contain: Morning, Afternoon, Evening,",
    input_variables= ["Day_p"]
)

budget_saving= PromptTemplate(
    template= '''At the end of each day,we required one practical money-saving suggestion for {time_blocks}, and output must be informat
                 Day 1
                 Morning: ...
                 Afternoon: ...
                 Evening: ...
                 Budget Tip: ...
                 Day 2

                 Morning: ...
                 Afternoon: ...
                 Evening: ...
                 Budget Tip: ...
                 (continue till all days) like that ''',

   input_variables= ["time_blocks"]
)

chain= Day_p | llm | StrOutputParser() | time_blocks | llm | StrOutputParser() | budget_saving | llm | StrOutputParser()

response= chain.invoke({"city": city,"number_of_days":number_of_days, "travel_style":travel_style, "interests": interests})

print(response)
# Out:
# Enter your name: Divya
# Hey Divya, Enter your city: Pune,Maharashtra
# How many days you would travel: 5
# What is your travel style (relaxed/busy): relaxed
# What is your interest: food,adventure,chilling
# Here is your perfectly balanced 5-day Pune itinerary, restructured with practical money-saving tips for each day.
#
# ### **Day 1: The Soul of Old Pune (Heritage & Iconic Eats)**
# *   **Morning:** Start your journey at **Shaniwar Wada**, the historic seat of the Peshwa Empire. After exploring the ruins, walk to **Vaidya Upahar Gruha** or **Bedekar Misal** for an authentic, fiery Puneri Misal Pav to jumpstart your palate.
# *   **Afternoon:** Visit the **Raja Dinkar Kelkar Museum** to see a stunning collection of Indian artifacts. Follow this with a massive, unlimited Maharashtrian Thali at **Durvankur** or **Sukhanta**—be sure to try the *Puran Poli*.
# *   **Evening:** Take a relaxing walk around **Saras Baug** and its Ganpati temple. Afterward, cool down at **Sujata Mastani** in Sadashiv Peth for their legendary thick milkshakes. End the day with a spicy Mutton/Chicken *Rassa* dinner at **Maratha Samrat**.
# *   **Budget Tip:** Most heritage sites in Old Pune (Shaniwar Wada, Nana Wada, etc.) are within walking distance of each other. Instead of taking multiple rickshaws, explore on foot or use a "PMPML" public bus for just ₹5–₹10 to save significantly on transit.
#
# ### **Day 2: Adventure & Clouds (Sinhagad Fort)**
# *   **Morning:** Take an early morning drive or a 40-minute trek up to **Sinhagad Fort**. The sunrise view is unmatched. For breakfast, eat **Pithla Bhakri** (gram flour curry) with *Thecha* (garlic-chili chutney) served by local vendors at the top.
# *   **Afternoon:** Drive down and stop at the **Khadakwasla Dam** backwaters. It’s the perfect spot to sit by the water and enjoy roasted corn (*Bhutta*) from the street vendors.
# *   **Evening:** Head to **Viman Nagar**. Spend time browsing **Phoenix Marketcity** or exploring the trendy cafes. Cap off the night with a rooftop dinner at **Atmosphere 6** for a panoramic view of the city skyline.
# *   **Budget Tip:** If you aren't trekking, avoid hiring a private cab for the whole day. Take a "Share-a-Seat" Jeep from the base of Sinhagad (Donje Phata) to the top; it’s a fraction of the cost and a very local experience.
#
# ### **Day 3: High Adrenaline & Lake Vibes (Kamshet/Pawna)**
# *   **Morning:** Head out early to **Kamshet** (1.5 hours away), the paragliding capital of India, for a tandem flight over the mountains.
# *   **Afternoon:** Stop at a local **Dhaba** on the Old Pune-Mumbai Highway for a rustic lunch of *Dal Tadka* and *Tandoori Roti*. Afterward, head to **Pawna Lake** to relax by the reservoir or try light kayaking.
# *   **Evening:** Return to Pune and head to **FC Road** for "Bun Maska" and "Irani Chai" at the legendary **Cafe Goodluck**. It’s the ultimate spot to soak in the city's student culture.
# *   **Budget Tip:** Instead of a private rental car to Kamshet, take the **Pune Local Train** from Pune Station or Shivajinagar to Kamshet Station. It is incredibly cheap, avoids highway traffic, and runs frequently.
#
# ### **Day 4: The Cosmopolitan Vibe (Koregaon Park)**
# *   **Morning:** Visit the **Aga Khan Palace**, a serene memorial with beautiful Italian arches. Afterward, head into **Koregaon Park (KP)** for a long, lazy brunch at **The German Bakery** or **Yogi Tree**.
# *   **Afternoon:** Wander through the lush, banyan-lined lanes of KP. Visit the **Osho Teerth Park**, a hidden Japanese-style zen garden that offers a peaceful escape from the city noise.
# *   **Evening:** Experience Pune’s famous nightlife. Start with craft beers at **Effingut** or **Independence Brewing Co.**, then move to **Malaka Spice** for fine dining or grab a burger at **Burger 11**.
# *   **Budget Tip:** Koregaon Park is expensive, but many high-end bars offer **Happy Hours** (usually 4 PM to 8 PM) or 1+1 deals on drinks. Use apps like Zomato or Swiggy Dineout to book your table and get up to 25–50% off your total bill.
#
# ### **Day 5: Scenic Drives & Mountain Breezes (Mulshi)**
# *   **Morning:** Take a scenic drive toward **Mulshi Dam**. If you go during monsoon or winter, the road through **Tamhini Ghat** is spectacular, featuring misty forest trails and seasonal waterfalls.
# *   **Afternoon:** Enjoy a relaxed lunch at **Basho’s**, a lakeside restaurant known for its great views. It’s the perfect place to reflect on your trip.
# *   **Evening:** Return to the city for final street shopping on **FC Road**. Pick up some *Bakharwadi* from **Chitale Bandhu** to take home. End your trip with a grand farewell dinner at **Paasha (JW Marriott)** for the best 360-degree views of Pune.
# *   **Budget Tip:** For your farewell at Paasha, you don't need to order a full course meal to enjoy the view. Visit for **"Sundowners"** (drinks and appetizers) to experience the luxury atmosphere and the skyline without the heavy price tag of a formal dinner.
